# %% [markdown]
# #Task 3.2 b.) -  Mutli-class classifier using PySpark .ipynb
# By Oluwatobi

# %% [markdown]
# **Setting Up PySpark in Colab**

# %%
#Update system packages
# !sudo apt-get update
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Get:7 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [1,390 kB]
# Get:8 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease [18.1 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,325 kB]
# Hit:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,059 kB]
# Get:12 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [1,676 kB]
# ...

# %%
#Next we will install Java
# !sudo apt install default-jdk
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   default-jdk-headless default-jre default-jre-headless fonts-dejavu-core
#   fonts-dejavu-extra libatk-wrapper-java libatk-wrapper-java-jni libfontenc1
#   libice-dev libsm-dev libxkbfile1 libxt-dev libxtst6 libxxf86dga1
#   openjdk-11-jdk openjdk-11-jre x11-utils
# Suggested packages:
#   libice-doc libsm-doc libxt-doc openjdk-11-demo openjdk-11-source visualvm
#   mesa-utils
# The following NEW packages will be installed:
#   default-jdk default-jdk-headless default-jre default-jre-headless
#   fonts-dejavu-core fonts-dejavu-extra libatk-wrapper-java
#   libatk-wrapper-java-jni libfontenc1 libice-dev libsm-dev libxkbfile1
#   libxt-dev libxtst6 libxxf86dga1 openjdk-11-jdk openjdk-11-jre x11-utils
# 0 upgraded, 18 newly installed, 0 to remove and 34 not upgraded.
# Need to get 5,514 kB of archives.
# ...

# %%
#Next, for Real-Time Live environment; we will Download Apache Spark and extract
# !wget https://archive.apache.org/dist/spark/spark-3.2.0/spark-3.2.0-bin-hadoop3.2.tgz
# !tar xvf spark-3.2.0-bin-hadoop3.2.tgz
# Out:
# --2024-01-25 22:25:38--  https://archive.apache.org/dist/spark/spark-3.2.0/spark-3.2.0-bin-hadoop3.2.tgz
# Resolving archive.apache.org (archive.apache.org)... 65.108.204.189, 2a01:4f9:1a:a084::2
# Connecting to archive.apache.org (archive.apache.org)|65.108.204.189|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 300965906 (287M) [application/x-gzip]
# Saving to: ‘spark-3.2.0-bin-hadoop3.2.tgz’
#
# spark-3.2.0-bin-had 100%[===================>] 287.02M  22.7MB/s    in 13s
#
# 2024-01-25 22:25:52 (21.4 MB/s) - ‘spark-3.2.0-bin-hadoop3.2.tgz’ saved [300965906/300965906]
#
# spark-3.2.0-bin-hadoop3.2/
# spark-3.2.0-bin-hadoop3.2/NOTICE
# spark-3.2.0-bin-hadoop3.2/kubernetes/
# spark-3.2.0-bin-hadoop3.2/kubernetes/tests/
# spark-3.2.0-bin-hadoop3.2/kubernetes/tests/python_executable_check.py
# spark-3.2.0-bin-hadoop3.2/kubernetes/tests/autoscale.py
# spark-3.2.0-bin-hadoop3.2/kubernetes/tests/worker_memory_check.py
# ...

# %%
#Install PySpark: the Python API for Apache Spark
# !pip install -q findspark
# !pip install pyspark
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.9/316.9 MB 2.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyspark: filename=pyspark-3.5.0-py2.py3-none-any.whl size=317425345 sha256=60a3a2f071fe137c033383417535aae327734f1b9d2c40933eb36847e3c6cef5
#   Stored in directory: /root/.cache/pip/wheels/41/4e/10/c2cf2467f71c678cfc8a6b9ac9241e5e44a01940da8fbb17fc
# Successfully built pyspark
# ...

# %%
#Next we will set the environment path; setting the environment variables JAVA_HOME and SPARK_HOME using the Python os module
import os

# Set Java and Spark home for Spark 3.5.0
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-11-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.5.0-bin-hadoop3.5"

# %%
# !pip install -q findspark

# %%
#Running a local SparkSession:  Employing the findspark library to locate the Spark installation,
#sets up the Spark environment, and creates a Spark session named spark for testing and development in a local setting.
import findspark
findspark.init()
from pyspark.sql import SparkSession
spark = SparkSession.builder.master("local[*]").getOrCreate()

# %%
# Check the pyspark version
import pyspark
print(pyspark.__version__)
# Out:
# 3.5.0

# %%
from pyspark.sql import SparkSession
# Numerical analysis package
import numpy as np
# Package to work with data
import pandas as pd
# Package for Matplotlib Pyplot
# Pyplot is a collection of functions in the popular visualization package Matplotlib.
import matplotlib as mpl
import matplotlib.pyplot as plt
# Package for Seaborn
# Seaborn is a Python data visualization library built on top of Matplotlib.
import seaborn as sns
from pyspark.ml.linalg import DenseMatrix, Vectors
from pyspark.ml.stat import Correlation
import json
#PySpark SQL Package
import pyspark.sql.functions as F
import pyspark.sql
from pyspark.sql.functions import col, skewness, kurtosis
from pyspark.context import SparkContext
from pyspark.sql.functions import *
from pyspark.sql.functions import isnan, when, count, col
from pyspark.sql.functions import when
from pyspark.sql.functions import UserDefinedFunction
from pyspark.sql.functions import from_unixtime, unix_timestamp
from pyspark.sql.types import StringType
from datetime import date, timedelta, datetime
import time

# %% [markdown]
# **Connect/Mount Google Drive to Colab**

# %%
#Connect/Mount Google Drive to Colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Define the UNSW-NB15 Dataframe**

# %%
# Load data CSV without header
data_csv_path = "/content/drive/MyDrive/UNSW-NB15.csv"  # Replace with the actual path to your data_dataset.csv file
data = spark.read.csv(data_csv_path, header=False, inferSchema=True)

# Show the resulting DataFrame with column names
data.show()
# Out:
# +----------+-----+-------------+-----+---+---+------------+-----+------+---+----+----+----+--------+---------+---------+----+----+----+----+----------+----------+----+----+----+----+----------+---------+----------+----------+------------+------------+------------+------------+------------+----+----+----+----+----+----+----+----+----+----+----+----+----+----+
# |       _c0|  _c1|          _c2|  _c3|_c4|_c5|         _c6|  _c7|   _c8|_c9|_c10|_c11|_c12|    _c13|     _c14|     _c15|_c16|_c17|_c18|_c19|      _c20|      _c21|_c22|_c23|_c24|_c25|      _c26|     _c27|      _c28|      _c29|        _c30|        _c31|        _c32|        _c33|        _c34|_c35|_c36|_c37|_c38|_c39|_c40|_c41|_c42|_c43|_c44|_c45|_c46|_c47|_c48|
# ...

# %%
#Show Columns
data.columns
# Out:
# ['_c0',
#  '_c1',
#  '_c2',
#  '_c3',
#  '_c4',
#  '_c5',
#  '_c6',
#  '_c7',
#  '_c8',
#  '_c9',
#  '_c10',
#  '_c11',
#  '_c12',
#  '_c13',
#  '_c14',
#  '_c15',
#  '_c16',
#  '_c17',
#  '_c18',
#  '_c19',
#  '_c20',
#  '_c21',
#  '_c22',
#  '_c23',
#  '_c24',
#  '_c25',
#  '_c26',
#  '_c27',
#  '_c28',
#  '_c29',
#  '_c30',
#  '_c31',
#  '_c32',
#  '_c33',
#  '_c34',
#  '_c35',
#  '_c36',
#  '_c37',
#  '_c38',
#  '_c39',
#  '_c40',
#  '_c41',
#  '_c42',
#  '_c43',
#  '_c44',
#  '_c45',
#  '_c46',
#  '_c47',
#  '_c48']

# %%
#We will now replace columns 0 to 48 with the names in the features dataset
#Renaming the Columns Header
UNSWNB15 = data.withColumnRenamed('_c0','srcip') \
.withColumnRenamed('_c1','sport') \
.withColumnRenamed('_c2','dstip') \
.withColumnRenamed('_c3','dsport') \
.withColumnRenamed('_c4','proto') \
.withColumnRenamed('_c5','state') \
.withColumnRenamed('_c6','dur') \
.withColumnRenamed('_c7','sbytes') \
.withColumnRenamed('_c8','dbytes') \
.withColumnRenamed('_c9','sttl') \
.withColumnRenamed('_c10','dttl') \
.withColumnRenamed('_c11','sloss') \
.withColumnRenamed('_c12','dloss') \
.withColumnRenamed('_c13','service') \
.withColumnRenamed('_c14','Sload') \
.withColumnRenamed('_c15','Dload') \
.withColumnRenamed('_c16','Spkts') \
.withColumnRenamed('_c17','Dpkts') \
.withColumnRenamed('_c18','swin') \
.withColumnRenamed('_c19','dwin') \
.withColumnRenamed('_c20','stcpb') \
.withColumnRenamed('_c21','dtcpb') \
.withColumnRenamed('_c22','smeansz') \
.withColumnRenamed('_c23','dmeansz') \
.withColumnRenamed('_c24','trans_depth') \
.withColumnRenamed('_c25','res_bdy_len') \
.withColumnRenamed('_c26','Sjit') \
.withColumnRenamed('_c27','Djit') \
.withColumnRenamed('_c28','Stime') \
.withColumnRenamed('_c29','Ltime') \
.withColumnRenamed('_c30','Spkt') \
.withColumnRenamed('_c31','Dpkt') \
.withColumnRenamed('_c32','tcprtt') \
.withColumnRenamed('_c33','synack') \
.withColumnRenamed('_c34','ackdat') \
.withColumnRenamed('_c35','is_sm_ips_ports') \
.withColumnRenamed('_c36','ct_state_ttl') \
.withColumnRenamed('_c37','ct_flw_http_mthd') \
.withColumnRenamed('_c38','is_ftp_login') \
.withColumnRenamed('_c39','ct_ftp_cmd') \
.withColumnRenamed('_c40','ct_srv_src') \
.withColumnRenamed('_c41','ct_srv_dst') \
.withColumnRenamed('_c42','ct_dst_ltm') \
.withColumnRenamed('_c43','ct_src_ ltm') \
.withColumnRenamed('_c44','ct_src_dport_ltm') \
.withColumnRenamed('_c45','ct_dst_sport_ltm') \
.withColumnRenamed('_c46','ct_dst_src_ltm') \
.withColumnRenamed('_c47','attack_cat') \
.withColumnRenamed('_c48','Label')

# %% [markdown]
# **Working with PySpark**

# %%
#Display Schema
UNSWNB15.printSchema()
# Out:
# root
#  |-- srcip: string (nullable = true)
#  |-- sport: integer (nullable = true)
#  |-- dstip: string (nullable = true)
#  |-- dsport: integer (nullable = true)
#  |-- proto: string (nullable = true)
#  |-- state: string (nullable = true)
#  |-- dur: double (nullable = true)
#  |-- sbytes: integer (nullable = true)
#  |-- dbytes: integer (nullable = true)
#  |-- sttl: integer (nullable = true)
#  |-- dttl: integer (nullable = true)
#  |-- sloss: integer (nullable = true)
#  |-- dloss: integer (nullable = true)
#  |-- service: string (nullable = true)
#  |-- Sload: double (nullable = true)
#  |-- Dload: double (nullable = true)
#  |-- Spkts: integer (nullable = true)
#  |-- Dpkts: integer (nullable = true)
#  |-- swin: integer (nullable = true)
#  |-- dwin: integer (nullable = true)
#  |-- stcpb: long (nullable = true)
#  |-- dtcpb: long (nullable = true)
#  |-- smeansz: integer (nullable = true)
#  |-- dmeansz: integer (nullable = true)
# ...

# %%
#Show Dataframe UNSWNB15
UNSWNB15.show()
# Out:
# +----------+-----+-------------+------+-----+-----+------------+------+------+----+----+-----+-----+--------+---------+---------+-----+-----+----+----+----------+----------+-------+-------+-----------+-----------+----------+---------+----------+----------+------------+------------+------------+------------+------------+---------------+------------+----------------+------------+----------+----------+----------+----------+-----------+----------------+----------------+--------------+----------+-----+
# ...

# %%
#Define dataset by by replacing null values in attack_cat column with normal
dataset = UNSWNB15.na.fill(value='normal',subset=["attack_cat"])
dataset.show()
# Out:
# +----------+-----+-------------+------+-----+-----+------------+------+------+----+----+-----+-----+--------+---------+---------+-----+-----+----+----+----------+----------+-------+-------+-----------+-----------+----------+---------+----------+----------+------------+------------+------------+------------+------------+---------------+------------+----------------+------------+----------+----------+----------+----------+-----------+----------------+----------------+--------------+----------+-----+
# ...

# %%
#Update all values in attack_cat column
#from pyspark.sql.functions import col,when
from pyspark.sql.functions import col,when
updated_dataset = dataset.withColumn("attack_cat", when( col("attack_cat")=="normal","Normal" )\
.when( col("attack_cat")=="Generic","Generic" )\
.when( col("attack_cat")=="Exploits","Exploits" )\
.when( col("attack_cat")=="DoS","DoS" )\
.when( col("attack_cat")=="Fuzzers","Fuzzers" )\
.when( col("attack_cat")=="Analysis","Analysis" )\
.when( col("attack_cat")=="Reconnaissance","Reconnaissance" )\
.when( col("attack_cat")=="Backdoors","Backdoors" )\
.when( col("attack_cat")=="Shellcode","Shellcode" )\
.when( col("attack_cat")=="Worms","Worms" )\
.when( col("attack_cat")=="Fuzzers ", "Fuzzers")\
.when( col("attack_cat")=="Reconnaissance ","Reconnaissance" )\
.when( col("attack_cat")=="Backdoor","Backdoors" )\
.when( col("attack_cat")=="Shellcode ","Shellcode" )\
)

# %%
#Confirm the dataset and the number of records
updated_dataset.show()
updated_dataset.count()
# Out:
# +----------+-----+-------------+------+-----+-----+------------+------+------+----+----+-----+-----+--------+---------+---------+-----+-----+----+----+----------+----------+-------+-------+-----------+-----------+----------+---------+----------+----------+------------+------------+------------+------------+------------+---------------+------------+----------------+------------+----------+----------+----------+----------+-----------+----------------+----------------+--------------+----------+-----+
# ...

# %%
#Setting up a PySpark machine learning pipeline for text classification using Logistic Regression
from pyspark.ml import Pipeline
from pyspark.ml.classification import LogisticRegression
from pyspark.ml.feature import HashingTF, Tokenizer
from pyspark.sql import Row
from pyspark.sql.functions import UserDefinedFunction
from pyspark.sql.types import *
import pyspark
from pyspark.context import SparkContext
from pyspark.sql.session import SparkSession
from py4j.protocol import Py4JJavaError

# %%
#Define Dataframe df
df = updated_dataset.select('srcip','attack_cat')

# %%
#Count and show Dataframe df
df.show()
df.count()
# Out:
# +----------+----------+
# |     srcip|attack_cat|
# +----------+----------+
# |59.166.0.3|    Normal|
# |59.166.0.0|    Normal|
# |59.166.0.5|    Normal|
# |59.166.0.9|    Normal|
# |59.166.0.8|    Normal|
# |59.166.0.3|    Normal|
# |59.166.0.7|    Normal|
# |59.166.0.3|    Normal|
# |59.166.0.9|    Normal|
# |59.166.0.7|    Normal|
# |59.166.0.1|    Normal|
# |59.166.0.0|    Normal|
# |59.166.0.1|    Normal|
# |59.166.0.8|    Normal|
# |59.166.0.8|    Normal|
# |59.166.0.8|    Normal|
# |59.166.0.1|    Normal|
# |59.166.0.3|    Normal|
# |59.166.0.0|    Normal|
# |59.166.0.0|    Normal|
# +----------+----------+
# only showing top 20 rows
# 2539739

# %%
#Drop null values in attack_cat
df = df.dropna(subset=('attack_cat'))

# %%
#Count and show Dataframe df
df.show()
df.count()
# Out:
# +----------+----------+
# |     srcip|attack_cat|
# +----------+----------+
# |59.166.0.3|    Normal|
# |59.166.0.0|    Normal|
# |59.166.0.5|    Normal|
# |59.166.0.9|    Normal|
# |59.166.0.8|    Normal|
# |59.166.0.3|    Normal|
# |59.166.0.7|    Normal|
# |59.166.0.3|    Normal|
# |59.166.0.9|    Normal|
# |59.166.0.7|    Normal|
# |59.166.0.1|    Normal|
# |59.166.0.0|    Normal|
# |59.166.0.1|    Normal|
# |59.166.0.8|    Normal|
# |59.166.0.8|    Normal|
# |59.166.0.8|    Normal|
# |59.166.0.1|    Normal|
# |59.166.0.3|    Normal|
# |59.166.0.0|    Normal|
# |59.166.0.0|    Normal|
# +----------+----------+
# only showing top 20 rows
# 2539739

# %%
#Give a name to the app.
spark = SparkSession.builder.appName("UNSWNB15ClassifierApp").getOrCreate()
df = updated_dataset.select('srcip','attack_cat')

# %%
#Now we Import necessary packages in PySpark for Feature Engineering

import pyspark.ml.feature
#Import the packages required to initialize the pipeline stages.
from pyspark.ml.feature import Tokenizer,StopWordsRemover,CountVectorizer,IDF
#Import package to add labels to our dataset
from pyspark.ml.feature import StringIndexer

# %%
#Sequential process starting from the tokenizer stage to the idf stage to create the pipeline stages.
tokenizer = Tokenizer(inputCol='srcip',outputCol='mytokens')
stopwords_remover = StopWordsRemover(inputCol='mytokens',outputCol='filtered_tokens')
vectorizer = CountVectorizer(inputCol='filtered_tokens',outputCol='rawFeatures')
idf = IDF(inputCol='rawFeatures',outputCol='vectorizedFeatures')

# %%
#Add labels into the attact_cat column to be used when predicting the type of Attack.
labelEncoder = StringIndexer(inputCol='attack_cat',outputCol='label').fit(df)

# %%
#Let's use a Label Encoder to transform the values in our DataFrame
dftest = labelEncoder.transform(df)

# %%
#Register the DataFrame as a temporary table in the SQLContext.
dftest.registerTempTable("dftest")
spark.sql("SELECT DISTINCT attack_cat, label FROM dftest ORDER BY label ASC").show()
# Out:
# /usr/local/lib/python3.10/dist-packages/pyspark/sql/dataframe.py:329: FutureWarning: Deprecated in 2.0, use createOrReplaceTempView instead.
#   warnings.warn("Deprecated in 2.0, use createOrReplaceTempView instead.", FutureWarning)
# +--------------+-----+
# |    attack_cat|label|
# +--------------+-----+
# |        Normal|  0.0|
# |       Generic|  1.0|
# |      Exploits|  2.0|
# |       Fuzzers|  3.0|
# |           DoS|  4.0|
# |Reconnaissance|  5.0|
# |      Analysis|  6.0|
# |     Backdoors|  7.0|
# |     Shellcode|  8.0|
# |         Worms|  9.0|
# +--------------+-----+

# %%
#See how the different Attacts are labeled
labelEncoder.transform(df).show()
# Out:
# +----------+----------+-----+
# |     srcip|attack_cat|label|
# +----------+----------+-----+
# |59.166.0.3|    normal|  0.0|
# |59.166.0.0|    normal|  0.0|
# |59.166.0.5|    normal|  0.0|
# |59.166.0.9|    normal|  0.0|
# |59.166.0.8|    normal|  0.0|
# |59.166.0.3|    normal|  0.0|
# |59.166.0.7|    normal|  0.0|
# |59.166.0.3|    normal|  0.0|
# |59.166.0.9|    normal|  0.0|
# |59.166.0.7|    normal|  0.0|
# |59.166.0.1|    normal|  0.0|
# |59.166.0.0|    normal|  0.0|
# |59.166.0.1|    normal|  0.0|
# |59.166.0.8|    normal|  0.0|
# |59.166.0.8|    normal|  0.0|
# |59.166.0.8|    normal|  0.0|
# |59.166.0.1|    normal|  0.0|
# |59.166.0.3|    normal|  0.0|
# |59.166.0.0|    normal|  0.0|
# |59.166.0.0|    normal|  0.0|
# +----------+----------+-----+
# only showing top 20 rows

# %%
# !pip install pyspark

# %%
import pyspark
from pyspark.sql import SparkSession

# %%
#This was the result before I updated the attact_cat in the dataset to define updated_dataset
#Register the DataFrame as a temporary table in the SQLContext.
# Use the correct variable name 'updated_dataset'
updated_dataset.registerTempTable("updateddf")
spark.sql("SELECT DISTINCT attack_cat, label FROM updateddf ORDER BY label ASC").show()
# Out:
# +--------------+-----+
# |    attack_cat|label|
# +--------------+-----+
# |        Normal|    0|
# |      Exploits|    1|
# |       Fuzzers|    1|
# |         Worms|    1|
# |           DoS|    1|
# |Reconnaissance|    1|
# |      Analysis|    1|
# |       Generic|    1|
# |     Shellcode|    1|
# |     Backdoors|    1|
# +--------------+-----+

# %%
#We will now assign numeric values to the Attact categories available in the dataset for easy predictions.
label_dict = {'normal':0.0,
    'Generic':1.0,
    'Exploits':2.0,
    'Fuzzers':3.0,
    'DoS':4.0,
    'Reconnaissance':5.0,
    'Analysis':6.0,
    'Backdoor':7.0,
    'Shellcode':8.0,
    'Worms':9.0}

# %%
#Add these labels into the dataset by using transform() method to add the labels to the respective subject categories.
df = labelEncoder.transform(df)

# %%
#The last stage involves building the model using the LogisticRegression algorithm.
(mainDataFrame,testDataFrame) = df.randomSplit((0.7,0.3),seed=42)
#70% of our dataset will be used for training and 30% for testing

# %%
#Import the LogisticRegression algorithm which we will use in building the model to perform classification.
from pyspark.ml.classification import LogisticRegression

# %%
#Creating estimator
#An estimator is a function that takes data as input,
#fits the data,
#and creates a model used to make predictions.
lr = LogisticRegression(featuresCol='vectorizedFeatures',labelCol='label')

# %%
#Import the Pipeline() method that we’ll use to build the model.
from pyspark.ml import Pipeline

# %%
#Fitting the five stages by add the initialized 5 stages into the Pipeline() method.
pipeline = Pipeline(stages=[tokenizer,stopwords_remover,vectorizer,idf,lr])

# %%
#Building model
#The model is built by fitting the model into the main dataset using the fit() method and passing the mainDataFrame as our parameter.
#Let’s initialize the model pipeline as lr_model.
lr_model = pipeline.fit(mainDataFrame)

# %%
#Testing model
#The model is tested using the test dataset to see if it can classify the course title and assign the right subject.
predictions = lr_model.transform(testDataFrame)

# %%
#To see if the model was able to do the right classification
predictions.show()
# Out:
# +-----------+----------+-----+-------------+---------------+---------------+--------------------+--------------------+--------------------+----------+
# |      srcip|attack_cat|label|     mytokens|filtered_tokens|    rawFeatures|  vectorizedFeatures|       rawPrediction|         probability|prediction|
# +-----------+----------+-----+-------------+---------------+---------------+--------------------+--------------------+--------------------+----------+
# |10.40.170.2|    Normal|  0.0|[10.40.170.2]|  [10.40.170.2]|(43,[24],[1.0])|(43,[24],[7.08854...|[14.4715369153014...|[0.99999850190007...|       0.0|
# |10.40.170.2|    Normal|  0.0|[10.40.170.2]|  [10.40.170.2]|(43,[24],[1.0])|(43,[24],[7.08854...|[14.4715369153014...|[0.99999850190007...|       0.0|
# |10.40.170.2|    Normal|  0.0|[10.40.170.2]|  [10.40.170.2]|(43,[24],[1.0])|(43,[24],[7.08854...|[14.4715369153014...|[0.99999850190007...|       0.0|
# ...

# %%
#To get all the available columns
predictions.columns
# Out:
# ['srcip',
#  'attack_cat',
#  'label',
#  'mytokens',
#  'filtered_tokens',
#  'rawFeatures',
#  'vectorizedFeatures',
#  'rawPrediction',
#  'probability',
#  'prediction']

# %%
#From the above columns, select the necessary columns used for predictions and view the first 10 rows.
predictions.select('rawPrediction','probability','attack_cat','label','prediction').show(10)
# Out:
# +--------------------+--------------------+----------+-----+----------+
# |       rawPrediction|         probability|attack_cat|label|prediction|
# +--------------------+--------------------+----------+-----+----------+
# |[14.4715369153014...|[0.99999850190007...|    Normal|  0.0|       0.0|
# |[14.4715369153014...|[0.99999850190007...|    Normal|  0.0|       0.0|
# |[14.4715369153014...|[0.99999850190007...|    Normal|  0.0|       0.0|
# |[14.4715369153014...|[0.99999850190007...|    Normal|  0.0|       0.0|
# |[14.4715369153014...|[0.99999850190007...|    Normal|  0.0|       0.0|
# |[14.4715369153014...|[0.99999850190007...|    Normal|  0.0|       0.0|
# |[14.4715369153014...|[0.99999850190007...|    Normal|  0.0|       0.0|
# |[14.4715369153014...|[0.99999850190007...|    Normal|  0.0|       0.0|
# |[14.4715369153014...|[0.99999850190007...|    Normal|  0.0|       0.0|
# |[14.4715369153014...|[0.99999850190007...|    Normal|  0.0|       0.0|
# ...

# %%
#Model evaluation
#This is checking the model accuracy to know how well we trained our model.
#Import the MulticlassClassificationEvaluator which will be used to evaluate the model and calculate the accuracy score.
from pyspark.ml.evaluation import MulticlassClassificationEvaluator

# %%
#The MulticlassClassificationEvaluator uses the label, column and prediction columns to calculate the accuracy.
#If the two-column matches, it increases the accuracy score of the model.
evaluator = MulticlassClassificationEvaluator(labelCol='label',predictionCol='prediction',metricName='accuracy')

# %%
accuracy = evaluator.evaluate(predictions)

# %%
#To get the accuracy
accuracy
# Out:
# 0.9451756602933821

# %%
#To perform a single prediction, prepare the sample input as a string using  the StringType() function.
#Import StringType package
from pyspark.sql.types import StringType

# %%
#Create a sample data frame made up of the srcip column.
example1 = spark.createDataFrame([
    ("Applying a multi-class classifier to classify data into ten classes (categories)",StringType())
],
["srcip"]

)

# %%
#Output the data frame without truncating
example1.show(truncate=False)
# Out:
# +--------------------------------------------------------------------------------+---+
# |srcip                                                                           |_2 |
# +--------------------------------------------------------------------------------+---+
# |Applying a multi-class classifier to classify data into ten classes (categories)|{} |
# +--------------------------------------------------------------------------------+---+

# %%
#Make a prediction
pred_example1 = lr_model.transform(example1)
#Show the output
pred_example1.show()
# Out:
# +--------------------+---+--------------------+--------------------+-----------+------------------+--------------------+--------------------+----------+
# |               srcip| _2|            mytokens|     filtered_tokens|rawFeatures|vectorizedFeatures|       rawPrediction|         probability|prediction|
# +--------------------+---+--------------------+--------------------+-----------+------------------+--------------------+--------------------+----------+
# |Applying a multi-...| {}|[applying, a, mul...|[applying, multi-...| (43,[],[])|        (43,[],[])|[12.5510057106748...|[0.99998704922070...|       0.0|
# +--------------------+---+--------------------+--------------------+-----------+------------------+--------------------+--------------------+----------+

# %%
#Show all the available columns
pred_example1.columns
# Out:
# ['srcip',
#  '_2',
#  'mytokens',
#  'filtered_tokens',
#  'rawFeatures',
#  'vectorizedFeatures',
#  'rawPrediction',
#  'probability',
#  'prediction']

# %%
#From the above columns, select the necessary columns that give the prediction results.
pred_example1.select('srcip','rawPrediction','probability','prediction').show()
# Out:
# +--------------------+--------------------+--------------------+----------+
# |               srcip|       rawPrediction|         probability|prediction|
# +--------------------+--------------------+--------------------+----------+
# |Applying a multi-...|[12.5510057106748...|[0.99998704922070...|       0.0|
# +--------------------+--------------------+--------------------+----------+

# %%
#Show label dictionary
label_dict
# Out:
# {'normal': 0.0,
#  'Generic': 1.0,
#  'Exploits': 2.0,
#  'Fuzzers': 3.0,
#  'DoS': 4.0,
#  'Reconnaissance': 5.0,
#  'Analysis': 6.0,
#  'Backdoor': 7.0,
#  'Shellcode': 8.0,
#  'Worms': 9.0}
